# %% [markdown]
# # Hello CS490!
# ## These are markup cells, used to easily annotate code or analysis

# %%
import pandas as pd
df = pd.read_csv('gamesModified.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23421 entries, 0 to 23420
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              23421 non-null  int64
#  1   SEASON          23421 non-null  int64
#  2   TEAM_ID_home    23421 non-null  int64
#  3   FG_PCT_home     23421 non-null  float64
#  4   FT_PCT_home     23421 non-null  float64
#  5   FG3_PCT_home    23421 non-null  float64
#  6   AST_home        23421 non-null  float64
#  7   REB_home        23421 non-null  float64
#  8   TEAM_ID_away    23421 non-null  int64
#  9   FG_PCT_away     23421 non-null  float64
#  10  FT_PCT_away     23421 non-null  float64
#  11  FG3_PCT_away    23421 non-null  float64
#  12  AST_away        23421 non-null  float64
#  13  REB_away        23421 non-null  float64
#  14  HOME_TEAM_WINS  23421 non-null  int64
# dtypes: float64(10), int64(5)
# memory usage: 2.7 MB

# %%
import matplotlib.pyplot as plt
import seaborn as sn 
corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
df = df.drop(columns=['ID'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23421 entries, 0 to 23420
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SEASON          23421 non-null  int64
#  1   TEAM_ID_home    23421 non-null  int64
#  2   FG_PCT_home     23421 non-null  float64
#  3   FT_PCT_home     23421 non-null  float64
#  4   FG3_PCT_home    23421 non-null  float64
#  5   AST_home        23421 non-null  float64
#  6   REB_home        23421 non-null  float64
#  7   TEAM_ID_away    23421 non-null  int64
#  8   FG_PCT_away     23421 non-null  float64
#  9   FT_PCT_away     23421 non-null  float64
#  10  FG3_PCT_away    23421 non-null  float64
#  11  AST_away        23421 non-null  float64
#  12  REB_away        23421 non-null  float64
#  13  HOME_TEAM_WINS  23421 non-null  int64
# dtypes: float64(10), int64(4)
# memory usage: 2.5 MB
