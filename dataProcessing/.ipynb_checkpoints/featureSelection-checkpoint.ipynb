# %%
import pandas as pd
df = pd.read_csv('games_large.csv')
df = df.drop(columns=['ID','GAME_DATE_EST','GAME_ID','SEASON'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16979 entries, 0 to 16978
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   HOME_TEAM_ID       16979 non-null  int64
#  1   HOME_W%            16979 non-null  float64
#  2   HOME_PS_W%         16979 non-null  float64
#  3   HOME_PS_FG%        16979 non-null  float64
#  4   HOME_PS_3P%        16979 non-null  float64
#  5   HOME_PS_FT%        16979 non-null  float64
#  6   HOME_PS_REB        16979 non-null  float64
#  7   HOME_PS_AST        16979 non-null  float64
#  8   HOME_PS_TOV        16979 non-null  float64
#  9   HOME_PS_STL        16979 non-null  float64
#  10  HOME_PS_BLK        16979 non-null  float64
#  11  HOME_PS_MOV        16979 non-null  float64
#  12  HOME_PS_PIE        16979 non-null  float64
#  13  HOME_PS_TEAM_DOFF  16979 non-null  float64
#  14  HOME_PS_OPP_DOFF   16979 non-null  float64
#  15  HOME_PS_NET_DOFF   16979 non-null  float64
#  16  HOME_PS_TEAM_SFF   16979 non-null  float64
#  17  HOME_PS_OPP_SFF    16979 non-null  float64
#  18  HOME_PS_NET_SFF    16979 non-null  float64
#  19  AWAY_TEAM_ID       16979 non-null  int64
#  20  AWAY_W%            16979 non-null  float64
#  21  AWAY_PS_W%         16979 non-null  float64
#  22  AWAY_PS_FG%        16979 non-null  float64
#  23  AWAY_PS_3P%        16979 non-null  float64
#  24  AWAY_PS_FT%        16979 non-null  float64
#  25  AWAY_PS_REB        16979 non-null  float64
#  26  AWAY_PS_AST        16979 non-null  float64
#  27  AWAY_PS_TOV        16979 non-null  float64
#  28  AWAY_PS_STL        16979 non-null  float64
#  29  AWAY_PS_BLK        16979 non-null  float64
#  30  AWAY_PS_MOV        16979 non-null  float64
#  31  AWAY_PS_PIE        16979 non-null  float64
#  32  AWAY_PS_TEAM_DOFF  16979 non-null  float64
#  33  AWAY_PS_OPP_DOFF   16979 non-null  float64
#  34  AWAY_PS_NET_DOFF   16979 non-null  float64
#  35  AWAY_PS_TEAM_SFF   16979 non-null  float64
#  36  AWAY_PS_OPP_SFF    16979 non-null  float64
#  37  AWAY_PS_NET_SFF    16979 non-null  float64
#  38  SPREAD             8602 non-null   float64
#  39  HOME_TEAM_WINS     16979 non-null  int64
#  40  MARGIN             16979 non-null  float64
# dtypes: float64(38), int64(3)
# memory usage: 5.3 MB

# %% [markdown]
# ## Correlation matrix to inspect values

# %%
import seaborn as sn
import numpy as np
import matplotlib.pyplot as plt 

corr = df.corr()
sn.set_theme(style="white")
f, ax = plt.subplots(figsize=(16, 16))

ax = sn.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap='coolwarm',
    square=True,
    mask=np.triu(corr)
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

plt.show()

# %% [markdown]
# ## Feature importance with decision tree classifier

# %%
# import necessary libraries
from sklearn.tree import DecisionTreeClassifier
# drop regression target
df = df.drop(columns=['MARGIN'])
df = df.dropna()

# seperate data
x = df.values[:, 0:((len(df.columns))-1)]
y = df.values[:, ((len(df.columns))-1)]

# define the model
model = DecisionTreeClassifier()
# fit the model
model.fit(x, y)
# get importance
importance = model.feature_importances_

# %%
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.xlabel("Feature #")
plt.ylabel("Importance")
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: 0, Score: 0.00000
# Feature: 1, Score: 0.12592
# Feature: 2, Score: 0.01160
# Feature: 3, Score: 0.01754
# Feature: 4, Score: 0.01959
# Feature: 5, Score: 0.01854
# Feature: 6, Score: 0.02305
# Feature: 7, Score: 0.01797
# Feature: 8, Score: 0.01778
# Feature: 9, Score: 0.01607
# Feature: 10, Score: 0.01390
# Feature: 11, Score: 0.01201
# Feature: 12, Score: 0.01384
# Feature: 13, Score: 0.01659
# Feature: 14, Score: 0.01624
# Feature: 15, Score: 0.00880
# Feature: 16, Score: 0.01355
# Feature: 17, Score: 0.01501
# Feature: 18, Score: 0.01196
# Feature: 19, Score: 0.00000
# Feature: 20, Score: 0.12800
# Feature: 21, Score: 0.01037
# Feature: 22, Score: 0.01958
# Feature: 23, Score: 0.02217
# Feature: 24, Score: 0.02218
# Feature: 25, Score: 0.02644
# Feature: 26, Score: 0.02350
# Feature: 27, Score: 0.02122
# Feature: 28, Score: 0.01918
# Feature: 29, Score: 0.01343
# Feature: 30, Score: 0.01008
# Feature: 31, Score: 0.00749
# Feature: 32, Score: 0.01293
# Feature: 33, Score: 0.01664
# Feature: 34, Score: 0.01231
# Feature: 35, Score: 0.01206
# Feature: 36, Score: 0.01846
# Feature: 37, Score: 0.01143
# Feature: 38, Score: 0.20258
